# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.cumsum(np.random.normal(0.01, 1, size=(100,))))

# %%
# Read the data
import pandas as pd
data = pd.read_csv('data_file.csv', delimiter='|', nrows=1000)
data.head()
data.rename(columns={'012024':'val2', '000137581448': 'val1', 'R':'Risk', 'Other':'Service'}, inplace=True)
data.drop(data.columns[5:], axis=1, inplace=True)
data = data.iloc[:, 1:]
data.head()
# Out:
#         val1   val2 Risk                 Service
# 0  137581448  22024    R                   Other
# 1  137581448  32024    R                   Other
# 2  137581449  12024    R  Pulte Mortgage, L.L.C.
# 3  137581449  22024    R  Pulte Mortgage, L.L.C.
# 4  137581449  32024    R  Pulte Mortgage, L.L.C.

# %%
# See Data
# plt.scatter(data['val2'], data['Risk'], s=50)
plt.hist(data['R'], 100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ophel\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 3
#       1 # See Data
# ...
